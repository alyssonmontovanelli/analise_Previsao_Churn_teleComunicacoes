# %% [markdown]
# # Deploy do melhor modelo

# %%
# Imports
import joblib
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Comparativo dos modelos

# %%
df_modelos = pd.read_csv("C:/Projetos Pessoais/DataScience/analise_Previsao_Churn_teleComunicacoes/dados/df_comparativo_modelos")

# %%
df_modelos
# Out:
#         Nome            Algoritmo  ROC_AUC Score  AUC Score  Acuracia
# 0  modelo_v1  Logistic Regression       0.740794   0.822777  0.752133
# 1  modelo_v2        Decision Tree       0.734916   0.810766  0.721801
# 2  modelo_v3                  KNN       0.726609   0.808208  0.689573
# 3  modelo_v4        Random Forest       0.700543   0.806495  0.763981
# 4  modelo_v5                  SVM       0.703066   0.740904  0.725118
# 5  modelo_v6          Naive Bayes       0.724418   0.795474  0.708057

# %% [markdown]
#  - Podemos verificar que os melhores modelos foram: Regressão Logística e Random Forest
#
#  ### Para esse problema, utilizarei o modelo_v1 (Logistic Regession), pelos seguintes motivos:
#  - Possui maior ROC_AUC e AUC Score, quando comparado ao Random Forest, essa métrica verifica a capacidade do modelo de verificar as classes positivas corretamente

# %%
# Carregar dataset para deploy

# %%
dados_deploy = pd.read_csv("C:/Projetos Pessoais/DataScience/analise_Previsao_Churn_teleComunicacoes/dados/dados_para_deploy")

# %%
dados_deploy
# Out:
#    customerID    sexo  idoso casado(a) possuiDependente  fidelidade  \
# 0  8496-DMZUK    Male      0        No               No          30
# 1  4472-LVYGI  Female      0       Yes              Yes           0
# 2  3156-QLHBO    Male      0        No              Yes           2
# 3  1183-CANVH  Female      0       Yes               No          23
# 4  2706-QZIHY  Female      0       Yes               No          15
# 5  8782-NUUOL    Male      0        No               No          60
# 6  2325-WINES  Female      0        No               No          32
# 7  0795-GMVQO    Male      0       Yes               No          67
# 8  3256-EZDBI    Male      1       Yes               No          51
# 9  2320-SLKMB  Female      0        No               No          26
#
#   servico_telefonico  multiplas_linhas servico_internet     seguranca_online  \
# 0                Yes               Yes      Fiber optic                  Yes
# 1                 No  No phone service              DSL                  Yes
# 2                Yes                No               No  No internet service
# 3                Yes                No              DSL                   No
# 4                Yes               Yes               No  No internet service
# 5                Yes                No              DSL                  Yes
# 6                Yes               Yes      Fiber optic                   No
# 7                Yes               Yes      Fiber optic                  Yes
# 8                 No  No phone service              DSL                   No
# 9                 No  No phone service              DSL                   No
#
#    ... protecao_dispositivo      suporte_tecnico         Streaming_TV  \
# 0  ...                  Yes                   No                   No
# 1  ...                  Yes                  Yes                  Yes
# 2  ...  No internet service  No internet service  No internet service
# 3  ...                   No                  Yes                  Yes
# 4  ...  No internet service  No internet service  No internet service
# 5  ...                  Yes                  Yes                  Yes
# 6  ...                  Yes                   No                  Yes
# 7  ...                  Yes                   No                  Yes
# 8  ...                   No                   No                   No
# 9  ...                  Yes                  Yes                  Yes
#
#       Streaming_filmes        contrato fatura_sem_papel  \
# 0                   No        One year               No
# 1                   No        Two year              Yes
# 2  No internet service  Month-to-month               No
# 3                   No        One year               No
# 4  No internet service        Two year               No
# 5                  Yes        One year               No
# 6                  Yes        One year              Yes
# 7                  Yes        One year               No
# 8                   No  Month-to-month              Yes
# 9                   No  Month-to-month              Yes
#
#              forma_pagamento valor_mensal  valor_total_pago  Churn
# 0  Bank transfer (automatic)        90.40           2820.65     No
# 1  Bank transfer (automatic)        52.55             52.55     No
# 2               Mailed check        19.25             48.35     No
# 3  Bank transfer (automatic)        60.00           1347.15     No
# 4               Mailed check        25.20            387.90     No
# 5               Mailed check        79.00           4801.10     No
# 6    Credit card (automatic)       104.05           3416.85     No
# 7    Credit card (automatic)       109.90           7332.40     No
# 8    Credit card (automatic)        29.45           1459.35     No
# 9    Credit card (automatic)        44.45           1183.80     No
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Pré Processamento dos novos dados

# %% [markdown]
# ### Carregando o modelo_v1 do disco

# %% [markdown]
# ### Gerando previsões para novo dataset
